# %% [markdown]
# ### ABOUT

# %%
# meta data of mtcars data set
# A data frame with 32 observations on 11 (numeric) variables.
# mpg = miles per gallon
# vs = engine (0 = vshaped, 1 = straight)
# am = transmission (0 = automatic, 1 = manual)

# %%
import pandas as pd
mtcars = pd.read_csv("mtcars.csv")

# %%
mtcars
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
mtcars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   model   32 non-null     object
#  1   mpg     32 non-null     float64
#  2   cyl     32 non-null     int64
#  3   disp    32 non-null     float64
#  4   hp      32 non-null     int64
#  5   drat    32 non-null     float64
#  6   wt      32 non-null     float64
#  7   qsec    32 non-null     float64
#  8   vs      32 non-null     int64
#  9   am      32 non-null     int64
#  10  gear    32 non-null     int64
#  11  carb    32 non-null     int64
# dtypes: float64(5), int64(6), object(1)
# memory usage: 3.1+ KB

# %%
sortedMpg =  mtcars.sort_values("mpg",ascending = False)
sortedMpg[0:1]
# Out:
#              model   mpg  cyl  disp  hp  drat     wt  qsec  vs  am  gear  carb
# 19  Toyota Corolla  33.9    4  71.1  65  4.22  1.835  19.9   1   1     4     1

# %%
# car with the best mpg is Toyota Corolla

# %%
sortedMpg =  mtcars.sort_values("mpg",ascending = True)
sortedMpg[0:1]
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 15  Lincoln Continental  10.4    8  460.0  215   3.0  5.424  17.82   0   0
#
#     gear  carb
# 15     3     4

# %%
# car with the worst mpg is Lincoln Continental with an mpg of 10.4

# %%
sortedHp =  mtcars.sort_values("hp",ascending =False)
sortedHp[0:1]
# Out:
#             model   mpg  cyl   disp   hp  drat    wt  qsec  vs  am  gear  carb
# 30  Maserati Bora  15.0    8  301.0  335  3.54  3.57  14.6   0   1     5     8

# %%
# car with the best hp is Maserati Bora with a hp of 301

# %%
mtcars["disp"].describe()
# Out:
# count     32.000000
# mean     230.721875
# std      123.938694
# min       71.100000
# 25%      120.825000
# 50%      196.300000
# 75%      326.000000
# max      472.000000
# Name: disp, dtype: float64

# %%
#the five number summary is as follows : q1-120.825 q2 - 196.3 q3- 326 min- 71.1 and max- 472

# %%
mtcars.hp.median()
# Out:
# 123.0

# %%
#median hp is 123.0

# %%
avgMpgMan = mtcars[mtcars["am"]==1]["mpg"].mean()
avgMpgAut = mtcars[mtcars["am"]==0]["mpg"].mean()

# %%
avgMpgMan
# Out:
# 24.39230769230769

# %%
avgMpgAut
# Out:
# 17.147368421052633

# %%
# from this we can conclude that average mpg of manual cars is 24.39230769230769 as compared to 17.147368421052633 of automatic cars

# %%
# histogram for mpg
mtcars["mpg"].hist()
# Out:
# <AxesSubplot:>

# %%
# box-plot for each cylinder type
mtcars.boxplot(by ='cyl', column=['mpg'])
# Out:
# <AxesSubplot:title={'center':'mpg'}, xlabel='cyl'>

# %%
import pandas as pd
mtcars = pd.read_csv("mtcars.csv")
manIndex = mtcars["am"]==1
autIndex = mtcars["am"]==0
pd.crosstab([mrca])
#pd.crosstab(manIndex,autIndex)
# Out:
# am     False  True
# am
# False      0     19
# True      13      0

# %%
# above is the crosstab displaying the number of automatic and manual cars

# %%
pd.crosstab(mtcars["am"],mtcars["cyl"])
# Out:
# cyl  4  6   8
# am
# 0    3  4  12
# 1    8  3   2

# %%
# above is the crosstab 0 = automatic 1 = manual

# %%
corr_wt_mpg = mtcars["wt"].corr(mtcars["mpg"])
corr_wt_mpg
# Out:
# -0.8676593765172281

# %%
# weight and mpg are -vely correlated by a measure of -0.8676593765172281S

# %%
dfpivot = pd.pivot_table(values = 'rating',index = 'userId',columns = 'movieId')
